# %%
import sc2reader

# %%
replay = sc2reader.load_replay("../data/input/pro_data/00e6ed3e34a8c6fa1b0a0aa62892bffc.SC2Replay")
replay

# %%
replay.map_name
# Out:
# 'Blackrock LE'

# %%
replay.game_length
# Out:
# Length(seconds=607)

# %%
is_valid_release = replay.release_string >= '5.0.16'
assert is_valid_release

# %%
player1 = 'Serral'
player2 = None
player1_race = 'Zerg'
player2_race = None
for player in replay.players:
    if player.name == 'Serral':
        assert player.play_race == 'Zerg'
    else:
        player2 = player.name
        player2_race = player.play_race
print(player1, player2, player1_race, player2_race)
# Out:
# Serral Geralt Zerg Protoss

# %%
for event in replay.events:
    if event.second < 1:
        continue

    if hasattr(event, "player") and event.player:
        if event.player.name == 'Serral':
            print(event.second, event.name, event)
    
    if event.second > 100:
        break
# Out:
# 1 SelectionEvent 00.01	Serral          SelectionEvent['Drone [3800001]', 'Drone [3880001]']
# 1 UpdateTargetUnitCommandEvent 00.01	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 1 CommandManagerStateEvent 00.01	Serral          CommandManagerStateEvent
# 1 SelectionEvent 00.01	Serral          SelectionEvent['Drone [38C0001]', 'Drone [3940001]']
# 1 UpdateTargetPointCommandEvent 00.01	Serral          Right Click; Location: (31.370849609375, 42.801513671875, 49115)
# 1 CommandManagerStateEvent 00.01	Serral          CommandManagerStateEvent
# 1 UpdateTargetUnitCommandEvent 00.01	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 1 CommandManagerStateEvent 00.01	Serral          CommandManagerStateEvent
# 2 CameraEvent 00.02	Serral          CameraEvent at (34.25, 39.44921875)
# 2 CameraEvent 00.02	Serral          CameraEvent at (34.25, 39.5859375)
# 2 SelectionEvent 00.02	Serral          SelectionEvent['Overlord [3980001]']
# 2 UpdateTargetPointCommandEvent 00.02	Serral          Right Click; Location: (44.614013671875, 48.50634765625, 49115)
# 2 CommandManagerStateEvent 00.02	Serral          CommandManagerStateEvent
# 2 SetControlGroupEvent 00.02	Serral          SetControlGroupEvent
# 2 SelectionEvent 00.02	Serral          SelectionEvent['Lair [3680001]']
# 2 SetControlGroupEvent 00.02	Serral          SetControlGroupEvent
# 3 GetControlGroupEvent 00.03	Serral          GetControlGroupEvent
# 3 GetControlGroupEvent 00.03	Serral          GetControlGroupEvent
# 3 SelectionEvent 00.03	Serral          SelectionEvent['Drone [3800001]']
# 3 UpdateTargetPointCommandEvent 00.03	Serral          Right Click; Location: (38.270263671875, 38.18896484375, 49115)
# 3 CommandManagerStateEvent 00.03	Serral          CommandManagerStateEvent
# 4 UpdateTargetUnitCommandEvent 00.04	Serral          Right Click; Target: MineralField [01BC0001]; Location: (37.0, 36.5, 49104)
# 4 CommandManagerStateEvent 00.04	Serral          CommandManagerStateEvent
# 4 GetControlGroupEvent 00.04	Serral          GetControlGroupEvent
# 4 GetControlGroupEvent 00.04	Serral          GetControlGroupEvent
# 4 GetControlGroupEvent 00.04	Serral          GetControlGroupEvent
# 4 GetControlGroupEvent 00.04	Serral          GetControlGroupEvent
# 4 GetControlGroupEvent 00.04	Serral          GetControlGroupEvent
# 5 SelectionEvent 00.05	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [3880001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]']
# 5 GetControlGroupEvent 00.05	Serral          GetControlGroupEvent
# 5 GetControlGroupEvent 00.05	Serral          GetControlGroupEvent
# 5 GetControlGroupEvent 00.05	Serral          GetControlGroupEvent
# 5 GetControlGroupEvent 00.05	Serral          GetControlGroupEvent
# 5 GetControlGroupEvent 00.05	Serral          GetControlGroupEvent
# 5 GetControlGroupEvent 00.05	Serral          GetControlGroupEvent
# 5 GetControlGroupEvent 00.05	Serral          GetControlGroupEvent
# 6 TargetPointCommandEvent 00.06	Serral          Right Click; Location: (114.2822265625, 151.16259765625, 41145)
# 6 GetControlGroupEvent 00.06	Serral          GetControlGroupEvent
# 6 CameraEvent 00.06	Serral          CameraEvent at (114.28125, 149.421875)
# 6 CommandManagerStateEvent 00.06	Serral          CommandManagerStateEvent
# 6 GetControlGroupEvent 00.06	Serral          GetControlGroupEvent
# 6 GetControlGroupEvent 00.06	Serral          GetControlGroupEvent
# 6 CommandManagerStateEvent 00.06	Serral          CommandManagerStateEvent
# 6 GetControlGroupEvent 00.06	Serral          GetControlGroupEvent
# 6 GetControlGroupEvent 00.06	Serral          GetControlGroupEvent
# 6 CameraEvent 00.06	Serral          CameraEvent at (36.5, 40.76171875)
# 6 GetControlGroupEvent 00.06	Serral          GetControlGroupEvent
# 7 GetControlGroupEvent 00.07	Serral          GetControlGroupEvent
# 7 GetControlGroupEvent 00.07	Serral          GetControlGroupEvent
# 7 GetControlGroupEvent 00.07	Serral          GetControlGroupEvent
# 7 GetControlGroupEvent 00.07	Serral          GetControlGroupEvent
# 7 GetControlGroupEvent 00.07	Serral          GetControlGroupEvent
# 7 GetControlGroupEvent 00.07	Serral          GetControlGroupEvent
# 7 GetControlGroupEvent 00.07	Serral          GetControlGroupEvent
# 8 GetControlGroupEvent 00.08	Serral          GetControlGroupEvent
# 8 GetControlGroupEvent 00.08	Serral          GetControlGroupEvent
# 8 GetControlGroupEvent 00.08	Serral          GetControlGroupEvent
# 8 GetControlGroupEvent 00.08	Serral          GetControlGroupEvent
# 8 GetControlGroupEvent 00.08	Serral          GetControlGroupEvent
# 8 GetControlGroupEvent 00.08	Serral          GetControlGroupEvent
# 8 GetControlGroupEvent 00.08	Serral          GetControlGroupEvent
# 9 SelectionEvent 00.09	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [3880001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]']
# 9 GetControlGroupEvent 00.09	Serral          GetControlGroupEvent
# 9 GetControlGroupEvent 00.09	Serral          GetControlGroupEvent
# 9 TargetPointCommandEvent 00.09	Serral          Right Click; Location: (45.864990234375, 45.566162109375, 49115)
# 9 UpdateTargetPointCommandEvent 00.09	Serral          Right Click; Location: (45.58837890625, 45.153564453125, 49115)
# 9 CommandManagerStateEvent 00.09	Serral          CommandManagerStateEvent
# 9 GetControlGroupEvent 00.09	Serral          GetControlGroupEvent
# 9 GetControlGroupEvent 00.09	Serral          GetControlGroupEvent
# 10 PlayerStatsEvent 00.10	 Player 1 - Serral (Zerg) - Stats Update
# 10 GetControlGroupEvent 00.10	Serral          GetControlGroupEvent
# 10 SelectionEvent 00.10	Serral          SelectionEvent['Drone [3800001]']
# 10 UpdateTargetUnitCommandEvent 00.10	Serral          Right Click; Target: MineralField [01BC0001]; Location: (37.0, 36.5, 49104)
# 10 CommandManagerStateEvent 00.10	Serral          CommandManagerStateEvent
# 10 UpdateTargetUnitCommandEvent 00.10	Serral          Right Click; Target: MineralField [01BC0001]; Location: (37.0, 36.5, 49104)
# 10 CommandManagerStateEvent 00.10	Serral          CommandManagerStateEvent
# 10 GetControlGroupEvent 00.10	Serral          GetControlGroupEvent
# 10 GetControlGroupEvent 00.10	Serral          GetControlGroupEvent
# 10 GetControlGroupEvent 00.10	Serral          GetControlGroupEvent
# 11 SelectionEvent 00.11	Serral          SelectionEvent['Larva [3740001]']
# 11 GetControlGroupEvent 00.11	Serral          GetControlGroupEvent
# 11 GetControlGroupEvent 00.11	Serral          GetControlGroupEvent
# 12 SelectionEvent 00.12	Serral          SelectionEvent['Larva [3740001]']
# 12 GetControlGroupEvent 00.12	Serral          GetControlGroupEvent
# 12 SelectionEvent 00.12	Serral          SelectionEvent['Larva [3740001]']
# 12 GetControlGroupEvent 00.12	Serral          GetControlGroupEvent
# 12 SelectionEvent 00.12	Serral          SelectionEvent['Larva [3740001]']
# 12 GetControlGroupEvent 00.12	Serral          GetControlGroupEvent
# 12 GetControlGroupEvent 00.12	Serral          GetControlGroupEvent
# 13 SelectionEvent 00.13	Serral          SelectionEvent['Larva [3740001]']
# 13 GetControlGroupEvent 00.13	Serral          GetControlGroupEvent
# 13 GetControlGroupEvent 00.13	Serral          GetControlGroupEvent
# 13 GetControlGroupEvent 00.13	Serral          GetControlGroupEvent
# 13 GetControlGroupEvent 00.13	Serral          GetControlGroupEvent
# 13 SelectionEvent 00.13	Serral          SelectionEvent['Larva [3740001]']
# 13 BasicCommandEvent 00.13	Serral          Ability (1860) - MorphDrone
# 13 CommandManagerStateEvent 00.13	Serral          CommandManagerStateEvent
# 13 CommandManagerStateEvent 00.13	Serral          CommandManagerStateEvent
# 13 CommandManagerStateEvent 00.13	Serral          CommandManagerStateEvent
# 13 CommandManagerStateEvent 00.13	Serral          CommandManagerStateEvent
# 14 CommandManagerStateEvent 00.14	Serral          CommandManagerStateEvent
# 14 SelectionEvent 00.14	Serral          SelectionEvent['Larva [3740001]']
# 14 GetControlGroupEvent 00.14	Serral          GetControlGroupEvent
# 14 SelectionEvent 00.14	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [3880001]', 'Drone [38C0001]', 'Drone [3900001]']
# 14 GetControlGroupEvent 00.14	Serral          GetControlGroupEvent
# 14 GetControlGroupEvent 00.14	Serral          GetControlGroupEvent
# 15 CameraEvent 00.15	Serral          CameraEvent at (44.328125, 51.625)
# 15 CameraEvent 00.15	Serral          CameraEvent at (44.328125, 51.62890625)
# 15 CameraEvent 00.15	Serral          CameraEvent at (44.38671875, 51.7109375)
# 15 TargetPointCommandEvent 00.15	Serral          Right Click; Location: (115.335693359375, 143.139404296875, 41176)
# 15 GetControlGroupEvent 00.15	Serral          GetControlGroupEvent
# 15 CameraEvent 00.15	Serral          CameraEvent at (115.33203125, 141.3984375)
# 15 CommandManagerStateEvent 00.15	Serral          CommandManagerStateEvent
# 15 UpdateTargetPointCommandEvent 00.15	Serral          Right Click; Location: (114.80908203125, 143.139404296875, 41224)
# 15 CommandManagerStateEvent 00.15	Serral          CommandManagerStateEvent
# 15 GetControlGroupEvent 00.15	Serral          GetControlGroupEvent
# 15 GetControlGroupEvent 00.15	Serral          GetControlGroupEvent
# 15 GetControlGroupEvent 00.15	Serral          GetControlGroupEvent
# 15 GetControlGroupEvent 00.15	Serral          GetControlGroupEvent
# 16 CameraEvent 00.16	Serral          CameraEvent at (114.80859375, 141.3984375)
# 16 GetControlGroupEvent 00.16	Serral          GetControlGroupEvent
# 16 GetControlGroupEvent 00.16	Serral          GetControlGroupEvent
# 16 CameraEvent 00.16	Serral          CameraEvent at (36.5, 40.76171875)
# 16 GetControlGroupEvent 00.16	Serral          GetControlGroupEvent
# 16 GetControlGroupEvent 00.16	Serral          GetControlGroupEvent
# 16 GetControlGroupEvent 00.16	Serral          GetControlGroupEvent
# 16 GetControlGroupEvent 00.16	Serral          GetControlGroupEvent
# 17 SelectionEvent 00.17	Serral          SelectionEvent['Drone [38C0001]']
# 17 TargetPointCommandEvent 00.17	Serral          Right Click; Location: (32.451171875, 42.420166015625, 49115)
# 17 TargetUnitCommandEvent 00.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 18 UpdateTargetUnitCommandEvent 00.18	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 18 CommandManagerStateEvent 00.18	Serral          CommandManagerStateEvent
# 18 TargetUnitCommandEvent 00.18	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 18 GetControlGroupEvent 00.18	Serral          GetControlGroupEvent
# 18 SelectionEvent 00.18	Serral          SelectionEvent['Drone [3C40001]']
# 18 UpdateTargetPointCommandEvent 00.18	Serral          Right Click; Location: (36.0234375, 38.031982421875, 49115)
# 18 CommandManagerStateEvent 00.18	Serral          CommandManagerStateEvent
# 19 UpdateTargetPointCommandEvent 00.19	Serral          Right Click; Location: (35.592529296875, 37.087646484375, 49115)
# 19 CommandManagerStateEvent 00.19	Serral          CommandManagerStateEvent
# 19 UpdateTargetUnitCommandEvent 00.19	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 19 CommandManagerStateEvent 00.19	Serral          CommandManagerStateEvent
# 19 UpdateTargetUnitCommandEvent 00.19	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 19 CommandManagerStateEvent 00.19	Serral          CommandManagerStateEvent
# 19 GetControlGroupEvent 00.19	Serral          GetControlGroupEvent
# 20 PlayerStatsEvent 00.20	 Player 1 - Serral (Zerg) - Stats Update
# 20 SelectionEvent 00.20	Serral          SelectionEvent['Drone [38C0001]']
# 20 UpdateTargetPointCommandEvent 00.20	Serral          Right Click; Location: (31.713623046875, 41.81201171875, 49115)
# 20 CommandManagerStateEvent 00.20	Serral          CommandManagerStateEvent
# 20 UpdateTargetPointCommandEvent 00.20	Serral          Right Click; Location: (30.623046875, 41.948486328125, 49115)
# 20 CommandManagerStateEvent 00.20	Serral          CommandManagerStateEvent
# 20 UpdateTargetUnitCommandEvent 00.20	Serral          Right Click; Target: MineralField [00580001]; Location: (30.0, 40.5, 49104)
# 20 CommandManagerStateEvent 00.20	Serral          CommandManagerStateEvent
# 21 UpdateTargetUnitCommandEvent 00.21	Serral          Right Click; Target: MineralField [00580001]; Location: (30.0, 40.5, 49104)
# 21 CommandManagerStateEvent 00.21	Serral          CommandManagerStateEvent
# 21 UpdateTargetUnitCommandEvent 00.21	Serral          Right Click; Target: MineralField [00580001]; Location: (30.0, 40.5, 49104)
# 21 CommandManagerStateEvent 00.21	Serral          CommandManagerStateEvent
# 21 GetControlGroupEvent 00.21	Serral          GetControlGroupEvent
# 21 UpdateTargetUnitCommandEvent 00.21	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 21 CommandManagerStateEvent 00.21	Serral          CommandManagerStateEvent
# 21 GetControlGroupEvent 00.21	Serral          GetControlGroupEvent
# 21 GetControlGroupEvent 00.21	Serral          GetControlGroupEvent
# 22 GetControlGroupEvent 00.22	Serral          GetControlGroupEvent
# 22 GetControlGroupEvent 00.22	Serral          GetControlGroupEvent
# 22 SelectionEvent 00.22	Serral          SelectionEvent['Larva [3700001]']
# 22 BasicCommandEvent 00.22	Serral          Ability (1860) - MorphDrone
# 22 CommandManagerStateEvent 00.22	Serral          CommandManagerStateEvent
# 22 CommandManagerStateEvent 00.22	Serral          CommandManagerStateEvent
# 22 CommandManagerStateEvent 00.22	Serral          CommandManagerStateEvent
# 22 CommandManagerStateEvent 00.22	Serral          CommandManagerStateEvent
# 22 CommandManagerStateEvent 00.22	Serral          CommandManagerStateEvent
# 22 CommandManagerStateEvent 00.22	Serral          CommandManagerStateEvent
# 22 CommandManagerStateEvent 00.22	Serral          CommandManagerStateEvent
# 22 SelectionEvent 00.22	Serral          SelectionEvent['Larva [3700001]']
# 22 GetControlGroupEvent 00.22	Serral          GetControlGroupEvent
# 23 SelectionEvent 00.23	Serral          SelectionEvent['Drone [3840001]']
# 23 SelectionEvent 00.23	Serral          SelectionEvent['Drone [3880001]']
# 24 TargetUnitCommandEvent 00.24	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 24 UpdateTargetUnitCommandEvent 00.24	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 24 CommandManagerStateEvent 00.24	Serral          CommandManagerStateEvent
# 24 GetControlGroupEvent 00.24	Serral          GetControlGroupEvent
# 24 SelectionEvent 00.24	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3C40001]']
# 24 GetControlGroupEvent 00.24	Serral          GetControlGroupEvent
# 24 SelectionEvent 00.24	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3C40001]']
# 25 GetControlGroupEvent 00.25	Serral          GetControlGroupEvent
# 25 SelectionEvent 00.25	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3C40001]']
# 25 GetControlGroupEvent 00.25	Serral          GetControlGroupEvent
# 25 GetControlGroupEvent 00.25	Serral          GetControlGroupEvent
# 26 CameraEvent 00.26	Serral          CameraEvent at (48.36328125, 56.8828125)
# 26 GetControlGroupEvent 00.26	Serral          GetControlGroupEvent
# 26 CameraEvent 00.26	Serral          CameraEvent at (36.5, 40.76171875)
# 26 SelectionEvent 00.26	Serral          SelectionEvent['Drone [3C40001]']
# 26 UpdateTargetUnitCommandEvent 00.26	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 26 CommandManagerStateEvent 00.26	Serral          CommandManagerStateEvent
# 27 UpdateTargetUnitCommandEvent 00.27	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 27 CommandManagerStateEvent 00.27	Serral          CommandManagerStateEvent
# 27 UpdateTargetUnitCommandEvent 00.27	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 27 CommandManagerStateEvent 00.27	Serral          CommandManagerStateEvent
# 27 UpdateTargetUnitCommandEvent 00.27	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 27 CommandManagerStateEvent 00.27	Serral          CommandManagerStateEvent
# 27 UpdateTargetUnitCommandEvent 00.27	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 27 CommandManagerStateEvent 00.27	Serral          CommandManagerStateEvent
# 27 UpdateTargetUnitCommandEvent 00.27	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 27 CommandManagerStateEvent 00.27	Serral          CommandManagerStateEvent
# 28 GetControlGroupEvent 00.28	Serral          GetControlGroupEvent
# 28 CameraEvent 00.28	Serral          CameraEvent at (90.05078125, 62.234375)
# 28 CameraEvent 00.28	Serral          CameraEvent at (73.1953125, 52.0703125)
# 28 CameraEvent 00.28	Serral          CameraEvent at (66.875, 46.1875)
# 28 CameraEvent 00.28	Serral          CameraEvent at (66.875, 41.91015625)
# 29 CameraEvent 00.29	Serral          CameraEvent at (60.02734375, 34.95703125)
# 29 CameraEvent 00.29	Serral          CameraEvent at (60.5703125, 35.21484375)
# 29 CameraEvent 00.29	Serral          CameraEvent at (64.00390625, 37.12109375)
# 29 CameraEvent 00.29	Serral          CameraEvent at (64.9921875, 37.70703125)
# 29 CameraEvent 00.29	Serral          CameraEvent at (65.88671875, 38.3203125)
# 29 CameraEvent 00.29	Serral          CameraEvent at (66.07421875, 38.05859375)
# 29 CameraEvent 00.29	Serral          CameraEvent at (66.23828125, 37.70703125)
# 29 CameraEvent 00.29	Serral          CameraEvent at (66.61328125, 37.37890625)
# 30 PlayerStatsEvent 00.30	 Player 1 - Serral (Zerg) - Stats Update
# 30 UpdateTargetPointCommandEvent 00.30	Serral          Right Click; Location: (68.333740234375, 44.796875, 41001)
# 30 CommandManagerStateEvent 00.30	Serral          CommandManagerStateEvent
# 30 CameraEvent 00.30	Serral          CameraEvent at (36.5, 40.76171875)
# 30 GetControlGroupEvent 00.30	Serral          GetControlGroupEvent
# 30 GetControlGroupEvent 00.30	Serral          GetControlGroupEvent
# 30 GetControlGroupEvent 00.30	Serral          GetControlGroupEvent
# 31 GetControlGroupEvent 00.31	Serral          GetControlGroupEvent
# 31 SelectionEvent 00.31	Serral          SelectionEvent['Larva [3C80001]']
# 32 SelectionEvent 00.32	Serral          SelectionEvent['Larva [3C00001]']
# 32 SetControlGroupEvent 00.32	Serral          SetControlGroupEvent
# 32 SelectionEvent 00.32	Serral          SelectionEvent['Drone [3CC0001]']
# 33 UpdateTargetPointCommandEvent 00.33	Serral          Right Click; Location: (30.92138671875, 44.175048828125, 49115)
# 33 CommandManagerStateEvent 00.33	Serral          CommandManagerStateEvent
# 33 SetControlGroupEvent 00.33	Serral          SetControlGroupEvent
# 33 UpdateTargetPointCommandEvent 00.33	Serral          Right Click; Location: (30.53466796875, 44.447998046875, 49115)
# 33 CommandManagerStateEvent 00.33	Serral          CommandManagerStateEvent
# 33 UpdateTargetUnitCommandEvent 00.33	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 33 CommandManagerStateEvent 00.33	Serral          CommandManagerStateEvent
# 33 GetControlGroupEvent 00.33	Serral          GetControlGroupEvent
# 33 UpdateTargetUnitCommandEvent 00.33	Serral          Right Click; Target: MineralField750 [00E00001]; Location: (29.0, 41.5, 49104)
# 33 CommandManagerStateEvent 00.33	Serral          CommandManagerStateEvent
# 34 SelectionEvent 00.34	Serral          SelectionEvent['Drone [3840001]', 'Drone [38C0001]', 'Drone [3940001]', 'Drone [3CC0001]']
# 34 GetControlGroupEvent 00.34	Serral          GetControlGroupEvent
# 34 GetControlGroupEvent 00.34	Serral          GetControlGroupEvent
# 34 GetControlGroupEvent 00.34	Serral          GetControlGroupEvent
# 34 SelectionEvent 00.34	Serral          SelectionEvent['Drone [3940001]']
# 34 SetControlGroupEvent 00.34	Serral          SetControlGroupEvent
# 35 UpdateTargetUnitCommandEvent 00.35	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 35 CommandManagerStateEvent 00.35	Serral          CommandManagerStateEvent
# 35 UpdateTargetUnitCommandEvent 00.35	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 35 CommandManagerStateEvent 00.35	Serral          CommandManagerStateEvent
# 35 UpdateTargetUnitCommandEvent 00.35	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 35 CommandManagerStateEvent 00.35	Serral          CommandManagerStateEvent
# 35 UpdateTargetUnitCommandEvent 00.35	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 35 CommandManagerStateEvent 00.35	Serral          CommandManagerStateEvent
# 36 UpdateTargetUnitCommandEvent 00.36	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 36 CommandManagerStateEvent 00.36	Serral          CommandManagerStateEvent
# 36 UpdateTargetUnitCommandEvent 00.36	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 36 CommandManagerStateEvent 00.36	Serral          CommandManagerStateEvent
# 36 UpdateTargetUnitCommandEvent 00.36	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 36 CommandManagerStateEvent 00.36	Serral          CommandManagerStateEvent
# 36 UpdateTargetUnitCommandEvent 00.36	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 36 CommandManagerStateEvent 00.36	Serral          CommandManagerStateEvent
# 36 UpdateTargetUnitCommandEvent 00.36	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 36 CommandManagerStateEvent 00.36	Serral          CommandManagerStateEvent
# 37 GetControlGroupEvent 00.37	Serral          GetControlGroupEvent
# 37 GetControlGroupEvent 00.37	Serral          GetControlGroupEvent
# 37 GetControlGroupEvent 00.37	Serral          GetControlGroupEvent
# 37 GetControlGroupEvent 00.37	Serral          GetControlGroupEvent
# 37 GetControlGroupEvent 00.37	Serral          GetControlGroupEvent
# 37 GetControlGroupEvent 00.37	Serral          GetControlGroupEvent
# 38 BasicCommandEvent 00.38	Serral          Ability (1862) - MorphOverlord
# 38 CommandManagerStateEvent 00.38	Serral          CommandManagerStateEvent
# 38 CommandManagerStateEvent 00.38	Serral          CommandManagerStateEvent
# 38 CommandManagerStateEvent 00.38	Serral          CommandManagerStateEvent
# 38 CommandManagerStateEvent 00.38	Serral          CommandManagerStateEvent
# 38 CommandManagerStateEvent 00.38	Serral          CommandManagerStateEvent
# 38 CommandManagerStateEvent 00.38	Serral          CommandManagerStateEvent
# 38 CommandManagerStateEvent 00.38	Serral          CommandManagerStateEvent
# 38 CommandManagerStateEvent 00.38	Serral          CommandManagerStateEvent
# 38 SelectionEvent 00.38	Serral          SelectionEvent['Larva [3C00001]']
# 38 SelectionEvent 00.38	Serral          SelectionEvent['Larva [3C00001]']
# 38 GetControlGroupEvent 00.38	Serral          GetControlGroupEvent
# 38 SelectionEvent 00.38	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [3880001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3C40001]', 'Drone [3CC0001]']
# 39 GetControlGroupEvent 00.39	Serral          GetControlGroupEvent
# 39 CameraEvent 00.39	Serral          CameraEvent at (66.61328125, 37.37890625)
# 39 CameraEvent 00.39	Serral          CameraEvent at (36.5, 40.76171875)
# 39 CameraEvent 00.39	Serral          CameraEvent at (66.61328125, 37.37890625)
# 40 PlayerStatsEvent 00.40	 Player 1 - Serral (Zerg) - Stats Update
# 40 CameraEvent 00.40	Serral          CameraEvent at (36.5, 40.76171875)
# 40 SelectionEvent 00.40	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3840001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3C40001]', 'Drone [3CC0001]', 'Drone [3D00001]']
# 40 GetControlGroupEvent 00.40	Serral          GetControlGroupEvent
# 40 SelectionEvent 00.40	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [3880001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3C40001]', 'Drone [3CC0001]', 'Drone [3D00001]']
# 40 GetControlGroupEvent 00.40	Serral          GetControlGroupEvent
# 41 TargetPointCommandEvent 00.41	Serral          Right Click; Location: (34.80078125, 38.133544921875, 49115)
# 41 UpdateTargetPointCommandEvent 00.41	Serral          Right Click; Location: (35.34619140625, 37.706298828125, 49115)
# 41 CommandManagerStateEvent 00.41	Serral          CommandManagerStateEvent
# 41 SelectionEvent 00.41	Serral          SelectionEvent['Drone [3D00001]']
# 41 UpdateTargetPointCommandEvent 00.41	Serral          Right Click; Location: (34.561279296875, 38.619140625, 49115)
# 41 CommandManagerStateEvent 00.41	Serral          CommandManagerStateEvent
# 42 UpdateTargetPointCommandEvent 00.42	Serral          Right Click; Location: (35.422607421875, 37.571044921875, 49115)
# 42 CommandManagerStateEvent 00.42	Serral          CommandManagerStateEvent
# 42 UpdateTargetPointCommandEvent 00.42	Serral          Right Click; Location: (35.425048828125, 37.436767578125, 49115)
# 42 CommandManagerStateEvent 00.42	Serral          CommandManagerStateEvent
# 42 SetControlGroupEvent 00.42	Serral          SetControlGroupEvent
# 42 UpdateTargetPointCommandEvent 00.42	Serral          Right Click; Location: (35.443359375, 37.252685546875, 49115)
# 42 CommandManagerStateEvent 00.42	Serral          CommandManagerStateEvent
# 42 UpdateTargetUnitCommandEvent 00.42	Serral          Right Click; Target: Drone [03C40001]; Location: (35.705078125, 37.12060546875, 49104)
# 42 CommandManagerStateEvent 00.42	Serral          CommandManagerStateEvent
# 43 UpdateTargetUnitCommandEvent 00.43	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 43 CommandManagerStateEvent 00.43	Serral          CommandManagerStateEvent
# 43 GetControlGroupEvent 00.43	Serral          GetControlGroupEvent
# 43 UpdateTargetPointCommandEvent 00.43	Serral          Right Click; Location: (45.999267578125, 45.218505859375, 49115)
# 43 CommandManagerStateEvent 00.43	Serral          CommandManagerStateEvent
# 44 SelectionEvent 00.44	Serral          SelectionEvent['Larva [3700002]', 'Larva [3C80001]']
# 44 SelectionEvent 00.44	Serral          SelectionEvent['Drone [3880001]']
# 44 SetControlGroupEvent 00.44	Serral          SetControlGroupEvent
# 45 UpdateTargetUnitCommandEvent 00.45	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 45 CommandManagerStateEvent 00.45	Serral          CommandManagerStateEvent
# 45 UpdateTargetUnitCommandEvent 00.45	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 45 CommandManagerStateEvent 00.45	Serral          CommandManagerStateEvent
# 45 GetControlGroupEvent 00.45	Serral          GetControlGroupEvent
# 45 SelectionEvent 00.45	Serral          SelectionEvent['Larva [3700002]', 'Larva [3C80001]']
# 45 BasicCommandEvent 00.45	Serral          Ability (1860) - MorphDrone
# 45 SelectionEvent 00.45	Serral          SelectionEvent['Larva [3700002]']
# 45 GetControlGroupEvent 00.45	Serral          GetControlGroupEvent
# 45 TargetPointCommandEvent 00.45	Serral          Right Click; Location: (36.045654296875, 37.237060546875, 49115)
# 46 UpdateTargetUnitCommandEvent 00.46	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 46 CommandManagerStateEvent 00.46	Serral          CommandManagerStateEvent
# 46 UpdateTargetUnitCommandEvent 00.46	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 46 CommandManagerStateEvent 00.46	Serral          CommandManagerStateEvent
# 46 UpdateTargetUnitCommandEvent 00.46	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 46 CommandManagerStateEvent 00.46	Serral          CommandManagerStateEvent
# 46 UpdateTargetUnitCommandEvent 00.46	Serral          Right Click; Target: MineralField [00BC0001]; Location: (34.0, 36.5, 49104)
# 46 CommandManagerStateEvent 00.46	Serral          CommandManagerStateEvent
# 46 CameraEvent 00.46	Serral          CameraEvent at (66.61328125, 37.37890625)
# 47 CameraEvent 00.47	Serral          CameraEvent at (36.5, 40.76171875)
# 47 GetControlGroupEvent 00.47	Serral          GetControlGroupEvent
# 47 UpdateTargetUnitCommandEvent 00.47	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 47 CommandManagerStateEvent 00.47	Serral          CommandManagerStateEvent
# 47 CameraEvent 00.47	Serral          CameraEvent at (66.61328125, 37.37890625)
# 48 UpdateTargetPointCommandEvent 00.48	Serral          Right Click; Location: (70.304931640625, 46.42578125, 41292)
# 48 CommandManagerStateEvent 00.48	Serral          CommandManagerStateEvent
# 48 CameraEvent 00.48	Serral          CameraEvent at (36.5, 40.76171875)
# 48 SelectionEvent 00.48	Serral          SelectionEvent['Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [38C0001]', 'Drone [3940001]', 'Drone [3C40001]', 'Drone [3CC0001]', 'Drone [3D00001]']
# 49 GetControlGroupEvent 00.49	Serral          GetControlGroupEvent
# 49 SelectionEvent 00.49	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [38C0001]', 'Drone [3940001]', 'Drone [3C40001]', 'Drone [3CC0001]', 'Drone [3D00001]']
# 49 GetControlGroupEvent 00.49	Serral          GetControlGroupEvent
# 49 CameraEvent 00.49	Serral          CameraEvent at (66.61328125, 37.37890625)
# 49 CameraEvent 00.49	Serral          CameraEvent at (36.5, 40.76171875)
# 49 CameraEvent 00.49	Serral          CameraEvent at (66.61328125, 37.37890625)
# 49 CameraEvent 00.49	Serral          CameraEvent at (36.5, 40.76171875)
# 49 CameraEvent 00.49	Serral          CameraEvent at (66.61328125, 37.37890625)
# 49 UpdateTargetPointCommandEvent 00.49	Serral          Right Click; Location: (67.882568359375, 46.998291015625, 41098)
# 49 CommandManagerStateEvent 00.49	Serral          CommandManagerStateEvent
# 50 PlayerStatsEvent 00.50	 Player 1 - Serral (Zerg) - Stats Update
# 50 CommandManagerStateEvent 00.50	Serral          CommandManagerStateEvent
# 50 CameraEvent 00.50	Serral          CameraEvent at (36.5, 40.76171875)
# 50 SelectionEvent 00.50	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [3880001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3C40001]', 'Drone [3CC0001]', 'Drone [3D00001]']
# 50 GetControlGroupEvent 00.50	Serral          GetControlGroupEvent
# 50 GetControlGroupEvent 00.50	Serral          GetControlGroupEvent
# 51 CameraEvent 00.51	Serral          CameraEvent at (57.55078125, 68.8046875)
# 51 TargetPointCommandEvent 00.51	Serral          Ability (563) - ScanMove; Location: (116.916015625, 144.744140625, 41281)
# 51 UpdateTargetPointCommandEvent 00.51	Serral          Right Click; Location: (116.916015625, 144.744140625, 41281)
# 51 CommandManagerStateEvent 00.51	Serral          CommandManagerStateEvent
# 51 UpdateTargetPointCommandEvent 00.51	Serral          Right Click; Location: (116.916015625, 144.744140625, 41281)
# 51 CommandManagerStateEvent 00.51	Serral          CommandManagerStateEvent
# 52 CameraEvent 00.52	Serral          CameraEvent at (66.61328125, 37.37890625)
# 52 GetControlGroupEvent 00.52	Serral          GetControlGroupEvent
# 52 CameraEvent 00.52	Serral          CameraEvent at (36.5, 40.76171875)
# 53 SelectionEvent 00.53	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3840001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3CC0001]']
# 53 GetControlGroupEvent 00.53	Serral          GetControlGroupEvent
# 53 SelectionEvent 00.53	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [3880001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3CC0001]', 'Drone [3D00001]']
# 53 CameraEvent 00.53	Serral          CameraEvent at (66.61328125, 37.37890625)
# 54 CameraEvent 00.54	Serral          CameraEvent at (36.5, 40.76171875)
# 54 CameraEvent 00.54	Serral          CameraEvent at (66.61328125, 37.37890625)
# 54 CameraEvent 00.54	Serral          CameraEvent at (36.5, 40.76171875)
# 54 CameraEvent 00.54	Serral          CameraEvent at (66.61328125, 37.37890625)
# 54 CameraEvent 00.54	Serral          CameraEvent at (83.203125, 46.72265625)
# 54 CameraEvent 00.54	Serral          CameraEvent at (75.3046875, 53.67578125)
# 55 CameraEvent 00.55	Serral          CameraEvent at (60.02734375, 63.3046875)
# 55 CameraEvent 00.55	Serral          CameraEvent at (56.8671875, 66.515625)
# 55 CameraEvent 00.55	Serral          CameraEvent at (56.33984375, 67.046875)
# 55 CameraEvent 00.55	Serral          CameraEvent at (55.81640625, 67.58203125)
# 55 CameraEvent 00.55	Serral          CameraEvent at (55.6953125, 67.69921875)
# 55 CameraEvent 00.55	Serral          CameraEvent at (54.26171875, 67.32421875)
# 55 CameraEvent 00.55	Serral          CameraEvent at (53.65234375, 66.5703125)
# 55 CameraEvent 00.55	Serral          CameraEvent at (54.00390625, 66.3359375)
# 55 CameraEvent 00.55	Serral          CameraEvent at (54.9453125, 66.1015625)
# 55 CameraEvent 00.55	Serral          CameraEvent at (55.1796875, 66.125)
# 56 CameraEvent 00.56	Serral          CameraEvent at (55.296875, 66.1953125)
# 56 CameraEvent 00.56	Serral          CameraEvent at (55.3671875, 66.265625)
# 56 CameraEvent 00.56	Serral          CameraEvent at (36.5, 40.76171875)
# 56 CameraEvent 00.56	Serral          CameraEvent at (55.3671875, 66.265625)
# 56 CameraEvent 00.56	Serral          CameraEvent at (36.5, 40.76171875)
# 56 CameraEvent 00.56	Serral          CameraEvent at (55.3671875, 66.265625)
# 57 CameraEvent 00.57	Serral          CameraEvent at (90.578125, 38.69921875)
# 57 CameraEvent 00.57	Serral          CameraEvent at (91.6328125, 38.69921875)
# 57 CameraEvent 00.57	Serral          CameraEvent at (92.5, 38.86328125)
# 57 CameraEvent 00.57	Serral          CameraEvent at (93.11328125, 38.76953125)
# 57 CameraEvent 00.57	Serral          CameraEvent at (94.0078125, 39.1484375)
# 57 CameraEvent 00.57	Serral          CameraEvent at (93.7265625, 39.59375)
# 57 CameraEvent 00.57	Serral          CameraEvent at (93.41796875, 39.8984375)
# 58 CameraEvent 00.58	Serral          CameraEvent at (93.37109375, 39.96875)
# 58 CameraEvent 00.58	Serral          CameraEvent at (93.46484375, 39.96875)
# 58 CameraEvent 00.58	Serral          CameraEvent at (93.60546875, 39.96875)
# 58 CameraEvent 00.58	Serral          CameraEvent at (93.62890625, 39.9453125)
# 58 CameraEvent 00.58	Serral          CameraEvent at (93.65625, 39.9453125)
# 58 CameraEvent 00.58	Serral          CameraEvent at (36.5, 40.76171875)
# 58 GetControlGroupEvent 00.58	Serral          GetControlGroupEvent
# 58 GetControlGroupEvent 00.58	Serral          GetControlGroupEvent
# 59 GetControlGroupEvent 00.59	Serral          GetControlGroupEvent
# 59 GetControlGroupEvent 00.59	Serral          GetControlGroupEvent
# 59 CameraEvent 00.59	Serral          CameraEvent at (66.61328125, 37.37890625)
# 59 CameraEvent 00.59	Serral          CameraEvent at (36.5, 40.76171875)
# 59 CameraEvent 00.59	Serral          CameraEvent at (93.62890625, 39.96875)
# 60 PlayerStatsEvent 01.00	 Player 1 - Serral (Zerg) - Stats Update
# 60 CameraEvent 01.00	Serral          CameraEvent at (58.9765625, 64.91015625)
# 60 CameraEvent 01.00	Serral          CameraEvent at (58.44921875, 64.91015625)
# 60 CameraEvent 01.00	Serral          CameraEvent at (58.42578125, 65.875)
# 60 CameraEvent 01.00	Serral          CameraEvent at (57.01171875, 66.53125)
# 60 CameraEvent 01.00	Serral          CameraEvent at (56.21484375, 66.71875)
# 60 CameraEvent 01.00	Serral          CameraEvent at (55.6484375, 66.671875)
# 60 CameraEvent 01.00	Serral          CameraEvent at (55.2734375, 66.296875)
# 61 CameraEvent 01.01	Serral          CameraEvent at (55.296875, 66.296875)
# 61 CameraEvent 01.01	Serral          CameraEvent at (36.5, 40.76171875)
# 61 GetControlGroupEvent 01.01	Serral          GetControlGroupEvent
# 61 GetControlGroupEvent 01.01	Serral          GetControlGroupEvent
# 61 GetControlGroupEvent 01.01	Serral          GetControlGroupEvent
# 61 GetControlGroupEvent 01.01	Serral          GetControlGroupEvent
# 62 GetControlGroupEvent 01.02	Serral          GetControlGroupEvent
# 62 GetControlGroupEvent 01.02	Serral          GetControlGroupEvent
# 62 GetControlGroupEvent 01.02	Serral          GetControlGroupEvent
# 62 GetControlGroupEvent 01.02	Serral          GetControlGroupEvent
# 62 SelectionEvent 01.02	Serral          SelectionEvent['Larva [3C80001]', 'Larva [3DC0001]']
# 63 SelectionEvent 01.03	Serral          SelectionEvent['Overlord [3700003]']
# 63 BasicCommandEvent 01.03	Serral          Ability (1860) - MorphDrone
# 63 CommandManagerStateEvent 01.03	Serral          CommandManagerStateEvent
# 63 CommandManagerStateEvent 01.03	Serral          CommandManagerStateEvent
# 63 CommandManagerStateEvent 01.03	Serral          CommandManagerStateEvent
# 63 CommandManagerStateEvent 01.03	Serral          CommandManagerStateEvent
# 63 CommandManagerStateEvent 01.03	Serral          CommandManagerStateEvent
# 63 SelectionEvent 01.03	Serral          SelectionEvent['Larva [3C80001]', 'Larva [3DC0001]']
# 63 SelectionEvent 01.03	Serral          SelectionEvent['Drone [3E00001]']
# 63 GetControlGroupEvent 01.03	Serral          GetControlGroupEvent
# 64 GetControlGroupEvent 01.04	Serral          GetControlGroupEvent
# 64 SelectionEvent 01.04	Serral          SelectionEvent['Drone [3800001]', 'Drone [3880001]', 'Drone [3900001]', 'Drone [3C40001]', 'Drone [3D00001]', 'Drone [3E00001]']
# 64 GetControlGroupEvent 01.04	Serral          GetControlGroupEvent
# 64 GetControlGroupEvent 01.04	Serral          GetControlGroupEvent
# 65 SelectionEvent 01.05	Serral          SelectionEvent['Drone [3C40001]']
# 65 SetControlGroupEvent 01.05	Serral          SetControlGroupEvent
# 65 GetControlGroupEvent 01.05	Serral          GetControlGroupEvent
# 66 GetControlGroupEvent 01.06	Serral          GetControlGroupEvent
# 66 TargetUnitCommandEvent 01.06	Serral          Ability (1740) - Gather; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 UpdateTargetUnitCommandEvent 01.06	Serral          Right Click; Target: MineralField750 [02040001]; Location: (36.0, 35.5, 49104)
# 66 CommandManagerStateEvent 01.06	Serral          CommandManagerStateEvent
# 66 GetControlGroupEvent 01.06	Serral          GetControlGroupEvent
# 67 GetControlGroupEvent 01.07	Serral          GetControlGroupEvent
# 67 GetControlGroupEvent 01.07	Serral          GetControlGroupEvent
# 67 GetControlGroupEvent 01.07	Serral          GetControlGroupEvent
# 67 GetControlGroupEvent 01.07	Serral          GetControlGroupEvent
# 68 TargetUnitCommandEvent 01.08	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 69 SelectionEvent 01.09	Serral          SelectionEvent['Larva [3C80001]']
# 69 CameraEvent 01.09	Serral          CameraEvent at (66.61328125, 37.37890625)
# 69 UpdateTargetPointCommandEvent 01.09	Serral          Right Click; Location: (66.93505859375, 38.599365234375, 40994)
# 69 CommandManagerStateEvent 01.09	Serral          CommandManagerStateEvent
# 69 CameraEvent 01.09	Serral          CameraEvent at (36.5, 40.76171875)
# 69 SetControlGroupEvent 01.09	Serral          SetControlGroupEvent
# 69 GetControlGroupEvent 01.09	Serral          GetControlGroupEvent
# 69 SelectionEvent 01.09	Serral          SelectionEvent['Larva [3C80001]']
# 69 GetControlGroupEvent 01.09	Serral          GetControlGroupEvent
# 69 SelectionEvent 01.09	Serral          SelectionEvent['Larva [3C80001]']
# 69 GetControlGroupEvent 01.09	Serral          GetControlGroupEvent
# 69 SelectionEvent 01.09	Serral          SelectionEvent['Larva [3C80001]']
# 70 PlayerStatsEvent 01.10	 Player 1 - Serral (Zerg) - Stats Update
# 70 GetControlGroupEvent 01.10	Serral          GetControlGroupEvent
# 70 SelectionEvent 01.10	Serral          SelectionEvent['Larva [3E40001]']
# 70 BasicCommandEvent 01.10	Serral          Ability (1860) - MorphDrone
# 70 SelectionEvent 01.10	Serral          SelectionEvent['Larva [3E40001]']
# 70 CameraEvent 01.10	Serral          CameraEvent at (93.62890625, 39.96875)
# 70 CameraEvent 01.10	Serral          CameraEvent at (66.61328125, 37.37890625)
# 71 CameraEvent 01.11	Serral          CameraEvent at (93.62890625, 39.96875)
# 71 CameraEvent 01.11	Serral          CameraEvent at (36.5, 40.76171875)
# 71 CameraEvent 01.11	Serral          CameraEvent at (93.62890625, 39.96875)
# 71 CameraEvent 01.11	Serral          CameraEvent at (36.5, 40.76171875)
# 71 CameraEvent 01.11	Serral          CameraEvent at (93.62890625, 39.96875)
# 71 CameraEvent 01.11	Serral          CameraEvent at (36.5, 40.76171875)
# 71 CameraEvent 01.11	Serral          CameraEvent at (66.61328125, 37.37890625)
# 72 GetControlGroupEvent 01.12	Serral          GetControlGroupEvent
# 72 GetControlGroupEvent 01.12	Serral          GetControlGroupEvent
# 72 GetControlGroupEvent 01.12	Serral          GetControlGroupEvent
# 72 CameraEvent 01.12	Serral          CameraEvent at (36.5, 40.76171875)
# 72 GetControlGroupEvent 01.12	Serral          GetControlGroupEvent
# 72 GetControlGroupEvent 01.12	Serral          GetControlGroupEvent
# 72 GetControlGroupEvent 01.12	Serral          GetControlGroupEvent
# 73 SelectionEvent 01.13	Serral          SelectionEvent['Drone [3CC0001]']
# 73 TargetPointCommandEvent 01.13	Serral          Ability (561) - Patrol; Location: (32.06494140625, 42.438720703125, 49115)
# 73 TargetUnitCommandEvent 01.13	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 74 TargetUnitCommandEvent 01.14	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 74 UpdateTargetUnitCommandEvent 01.14	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 74 CommandManagerStateEvent 01.14	Serral          CommandManagerStateEvent
# 74 CameraEvent 01.14	Serral          CameraEvent at (66.61328125, 37.37890625)
# 74 CameraEvent 01.14	Serral          CameraEvent at (36.5, 40.76171875)
# 74 GetControlGroupEvent 01.14	Serral          GetControlGroupEvent
# 75 SelectionEvent 01.15	Serral          SelectionEvent['Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [38C0001]', 'Drone [3940001]', 'Drone [3CC0001]', 'Drone [3D00001]']
# 75 SelectionEvent 01.15	Serral          SelectionEvent['Drone [3780001]']
# 75 GetControlGroupEvent 01.15	Serral          GetControlGroupEvent
# 75 SelectionEvent 01.15	Serral          SelectionEvent['Drone [3940001]']
# 76 CameraEvent 01.16	Serral          CameraEvent at (66.61328125, 37.37890625)
# 76 CameraEvent 01.16	Serral          CameraEvent at (36.5, 40.76171875)
# 76 CameraEvent 01.16	Serral          CameraEvent at (66.61328125, 37.37890625)
# 76 CameraEvent 01.16	Serral          CameraEvent at (36.5, 40.76171875)
# 76 CameraEvent 01.16	Serral          CameraEvent at (66.61328125, 37.37890625)
# 76 CameraEvent 01.16	Serral          CameraEvent at (36.5, 40.76171875)
# 77 TargetUnitCommandEvent 01.17	Serral          Ability (1740) - Gather; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 UpdateTargetUnitCommandEvent 01.17	Serral          Right Click; Target: MineralField [01880001]; Location: (30.0, 42.5, 49104)
# 77 CommandManagerStateEvent 01.17	Serral          CommandManagerStateEvent
# 77 GetControlGroupEvent 01.17	Serral          GetControlGroupEvent
# 77 SelectionEvent 01.17	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3840001]', 'Drone [3880001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3CC0001]', 'Drone [3E00001]']
# 78 CameraEvent 01.18	Serral          CameraEvent at (66.61328125, 37.37890625)
# 78 GetControlGroupEvent 01.18	Serral          GetControlGroupEvent
# 78 CameraEvent 01.18	Serral          CameraEvent at (67.15625, 38.25)
# 78 GetControlGroupEvent 01.18	Serral          GetControlGroupEvent
# 78 CameraEvent 01.18	Serral          CameraEvent at (69.01171875, 41.46875)
# 78 GetControlGroupEvent 01.18	Serral          GetControlGroupEvent
# 78 CameraEvent 01.18	Serral          CameraEvent at (71.01171875, 46.31640625)
# 78 GetControlGroupEvent 01.18	Serral          GetControlGroupEvent
# 78 GetControlGroupEvent 01.18	Serral          GetControlGroupEvent
# 78 GetControlGroupEvent 01.18	Serral          GetControlGroupEvent
# 78 TargetPointCommandEvent 01.18	Serral          Right Click; Location: (70.561767578125, 50.756103515625, 40923)
# 79 CommandManagerStateEvent 01.19	Serral          CommandManagerStateEvent
# 79 CameraEvent 01.19	Serral          CameraEvent at (36.5, 40.76171875)
# 79 CameraEvent 01.19	Serral          CameraEvent at (66.61328125, 37.37890625)
# 79 CameraEvent 01.19	Serral          CameraEvent at (36.5, 40.76171875)
# 79 CameraEvent 01.19	Serral          CameraEvent at (66.61328125, 37.37890625)
# 79 CameraEvent 01.19	Serral          CameraEvent at (36.5, 40.76171875)
# 80 PlayerStatsEvent 01.20	 Player 1 - Serral (Zerg) - Stats Update
# 80 GetControlGroupEvent 01.20	Serral          GetControlGroupEvent
# 80 GetControlGroupEvent 01.20	Serral          GetControlGroupEvent
# 80 SelectionEvent 01.20	Serral          SelectionEvent['Drone [3EC0001]']
# 80 SelectionEvent 01.20	Serral          SelectionEvent['Drone [3EC0001]']
# 80 CameraEvent 01.20	Serral          CameraEvent at (66.61328125, 37.37890625)
# 80 UpdateTargetPointCommandEvent 01.20	Serral          Right Click; Location: (66.74560546875, 39.200927734375, 40946)
# 80 CommandManagerStateEvent 01.20	Serral          CommandManagerStateEvent
# 80 CameraEvent 01.20	Serral          CameraEvent at (36.5, 40.76171875)
# 81 CameraEvent 01.21	Serral          CameraEvent at (66.61328125, 37.37890625)
# 81 CameraEvent 01.21	Serral          CameraEvent at (36.5, 40.76171875)
# 81 GetControlGroupEvent 01.21	Serral          GetControlGroupEvent
# 81 SelectionEvent 01.21	Serral          SelectionEvent['Drone [3F00001]']
# 81 UpdateTargetPointCommandEvent 01.21	Serral          Right Click; Location: (29.636962890625, 40.14453125, 49115)
# 81 CommandManagerStateEvent 01.21	Serral          CommandManagerStateEvent
# 82 UpdateTargetUnitCommandEvent 01.22	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 82 CommandManagerStateEvent 01.22	Serral          CommandManagerStateEvent
# 82 UpdateTargetUnitCommandEvent 01.22	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 82 CommandManagerStateEvent 01.22	Serral          CommandManagerStateEvent
# 82 UpdateTargetPointCommandEvent 01.22	Serral          Right Click; Location: (29.29150390625, 39.81494140625, 49115)
# 82 CommandManagerStateEvent 01.22	Serral          CommandManagerStateEvent
# 83 UpdateTargetPointCommandEvent 01.23	Serral          Right Click; Location: (29.137451171875, 40.071533203125, 49115)
# 83 CommandManagerStateEvent 01.23	Serral          CommandManagerStateEvent
# 83 UpdateTargetUnitCommandEvent 01.23	Serral          Right Click; Target: MineralField750 [02840001]; Location: (30.0, 38.5, 49104)
# 83 CommandManagerStateEvent 01.23	Serral          CommandManagerStateEvent
# 83 CameraEvent 01.23	Serral          CameraEvent at (66.61328125, 37.37890625)
# 83 CameraEvent 01.23	Serral          CameraEvent at (36.5, 40.76171875)
# 84 SelectionEvent 01.24	Serral          SelectionEvent['Drone [37C0001]']
# 84 CameraEvent 01.24	Serral          CameraEvent at (66.61328125, 37.37890625)
# 84 CameraEvent 01.24	Serral          CameraEvent at (36.5, 40.76171875)
# 84 UpdateTargetUnitCommandEvent 01.24	Serral          Right Click; Target: MineralField750 [02840001]; Location: (30.0, 38.5, 49104)
# 84 CommandManagerStateEvent 01.24	Serral          CommandManagerStateEvent
# 84 UpdateTargetUnitCommandEvent 01.24	Serral          Right Click; Target: MineralField750 [02840001]; Location: (30.0, 38.5, 49104)
# 84 CommandManagerStateEvent 01.24	Serral          CommandManagerStateEvent
# 84 UpdateTargetUnitCommandEvent 01.24	Serral          Right Click; Target: MineralField750 [02840001]; Location: (30.0, 38.5, 49104)
# 84 CommandManagerStateEvent 01.24	Serral          CommandManagerStateEvent
# 85 UpdateTargetUnitCommandEvent 01.25	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 85 CommandManagerStateEvent 01.25	Serral          CommandManagerStateEvent
# 85 UpdateTargetUnitCommandEvent 01.25	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 85 CommandManagerStateEvent 01.25	Serral          CommandManagerStateEvent
# 85 UpdateTargetUnitCommandEvent 01.25	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 85 CommandManagerStateEvent 01.25	Serral          CommandManagerStateEvent
# 86 UpdateTargetUnitCommandEvent 01.26	Serral          Right Click; Target: MineralField750 [02840001]; Location: (30.0, 38.5, 49104)
# 86 CommandManagerStateEvent 01.26	Serral          CommandManagerStateEvent
# 86 UpdateTargetUnitCommandEvent 01.26	Serral          Right Click; Target: MineralField750 [02840001]; Location: (30.0, 38.5, 49104)
# 86 CommandManagerStateEvent 01.26	Serral          CommandManagerStateEvent
# 86 UpdateTargetUnitCommandEvent 01.26	Serral          Right Click; Target: MineralField750 [02840001]; Location: (30.0, 38.5, 49104)
# 86 CommandManagerStateEvent 01.26	Serral          CommandManagerStateEvent
# 86 UpdateTargetUnitCommandEvent 01.26	Serral          Right Click; Target: MineralField750 [02840001]; Location: (30.0, 38.5, 49104)
# 86 CommandManagerStateEvent 01.26	Serral          CommandManagerStateEvent
# 87 GetControlGroupEvent 01.27	Serral          GetControlGroupEvent
# 87 UpdateTargetUnitCommandEvent 01.27	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 87 CommandManagerStateEvent 01.27	Serral          CommandManagerStateEvent
# 87 GetControlGroupEvent 01.27	Serral          GetControlGroupEvent
# 88 CameraEvent 01.28	Serral          CameraEvent at (55.1015625, 45.23828125)
# 88 CameraEvent 01.28	Serral          CameraEvent at (56.08984375, 45.09765625)
# 88 CameraEvent 01.28	Serral          CameraEvent at (58.37109375, 44.76953125)
# 88 CameraEvent 01.28	Serral          CameraEvent at (61.12109375, 44.65234375)
# 88 UpdateTargetPointCommandEvent 01.28	Serral          Right Click; Location: (65.07666015625, 45.208984375, 41188)
# 88 CommandManagerStateEvent 01.28	Serral          CommandManagerStateEvent
# 88 UpdateTargetPointCommandEvent 01.28	Serral          Right Click; Location: (67.36083984375, 45.10791015625, 40986)
# 88 CommandManagerStateEvent 01.28	Serral          CommandManagerStateEvent
# 88 UpdateTargetPointCommandEvent 01.28	Serral          Right Click; Location: (67.933349609375, 43.4833984375, 40929)
# 88 CommandManagerStateEvent 01.28	Serral          CommandManagerStateEvent
# 89 GetControlGroupEvent 01.29	Serral          GetControlGroupEvent
# 89 CameraEvent 01.29	Serral          CameraEvent at (36.5, 40.76171875)
# 89 SelectionEvent 01.29	Serral          SelectionEvent['Drone [3C80002]']
# 89 UpdateTargetUnitCommandEvent 01.29	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 89 CommandManagerStateEvent 01.29	Serral          CommandManagerStateEvent
# 89 UpdateTargetUnitCommandEvent 01.29	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 89 CommandManagerStateEvent 01.29	Serral          CommandManagerStateEvent
# 90 PlayerStatsEvent 01.30	 Player 1 - Serral (Zerg) - Stats Update
# 90 UpdateTargetUnitCommandEvent 01.30	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 90 CommandManagerStateEvent 01.30	Serral          CommandManagerStateEvent
# 90 UpdateTargetUnitCommandEvent 01.30	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 90 CommandManagerStateEvent 01.30	Serral          CommandManagerStateEvent
# 90 UpdateTargetUnitCommandEvent 01.30	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 90 CommandManagerStateEvent 01.30	Serral          CommandManagerStateEvent
# 90 UpdateTargetUnitCommandEvent 01.30	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 90 CommandManagerStateEvent 01.30	Serral          CommandManagerStateEvent
# 90 UpdateTargetUnitCommandEvent 01.30	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 90 CommandManagerStateEvent 01.30	Serral          CommandManagerStateEvent
# 91 UpdateTargetUnitCommandEvent 01.31	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 91 CommandManagerStateEvent 01.31	Serral          CommandManagerStateEvent
# 91 CameraEvent 01.31	Serral          CameraEvent at (66.61328125, 37.37890625)
# 91 CameraEvent 01.31	Serral          CameraEvent at (93.62890625, 39.96875)
# 91 UpdateTargetPointCommandEvent 01.31	Serral          Right Click; Location: (95.20947265625, 41.828125, 40936)
# 91 CommandManagerStateEvent 01.31	Serral          CommandManagerStateEvent
# 92 GetControlGroupEvent 01.32	Serral          GetControlGroupEvent
# 92 CameraEvent 01.32	Serral          CameraEvent at (67.31640625, 41.88671875)
# 93 CameraEvent 01.33	Serral          CameraEvent at (93.62890625, 39.96875)
# 93 UpdateTargetPointCommandEvent 01.33	Serral          Right Click; Location: (95.4453125, 41.686279296875, 40947)
# 93 CommandManagerStateEvent 01.33	Serral          CommandManagerStateEvent
# 93 CommandManagerStateEvent 01.33	Serral          CommandManagerStateEvent
# 93 CameraEvent 01.33	Serral          CameraEvent at (36.5, 40.76171875)
# 93 GetControlGroupEvent 01.33	Serral          GetControlGroupEvent
# 93 SelectionEvent 01.33	Serral          SelectionEvent['Larva [3DC0002]']
# 93 BasicCommandEvent 01.33	Serral          Ability (1860) - MorphDrone
# 94 SelectionEvent 01.34	Serral          SelectionEvent['Larva [3DC0002]']
# 94 SelectionEvent 01.34	Serral          SelectionEvent['Drone [3C80002]']
# 94 TargetPointCommandEvent 01.34	Serral          Right Click; Location: (36.012451171875, 39.381103515625, 49115)
# 94 UpdateTargetPointCommandEvent 01.34	Serral          Right Click; Location: (33.625244140625, 38.706298828125, 49115)
# 94 CommandManagerStateEvent 01.34	Serral          CommandManagerStateEvent
# 94 UpdateTargetPointCommandEvent 01.34	Serral          Right Click; Location: (32.606201171875, 38.41015625, 49115)
# 94 CommandManagerStateEvent 01.34	Serral          CommandManagerStateEvent
# 95 GetControlGroupEvent 01.35	Serral          GetControlGroupEvent
# 96 SelectionEvent 01.36	Serral          SelectionEvent['Drone [3C80002]']
# 96 UpdateTargetUnitCommandEvent 01.36	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 96 CommandManagerStateEvent 01.36	Serral          CommandManagerStateEvent
# 96 UpdateTargetUnitCommandEvent 01.36	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 96 CommandManagerStateEvent 01.36	Serral          CommandManagerStateEvent
# 97 UpdateTargetUnitCommandEvent 01.37	Serral          Right Click; Target: MineralField750 [02840001]; Location: (30.0, 38.5, 49104)
# 97 CommandManagerStateEvent 01.37	Serral          CommandManagerStateEvent
# 97 UpdateTargetUnitCommandEvent 01.37	Serral          Right Click; Target: MineralField750 [02840001]; Location: (30.0, 38.5, 49104)
# 97 CommandManagerStateEvent 01.37	Serral          CommandManagerStateEvent
# 97 UpdateTargetPointCommandEvent 01.37	Serral          Right Click; Location: (30.36328125, 37.808837890625, 49115)
# 97 CommandManagerStateEvent 01.37	Serral          CommandManagerStateEvent
# 97 UpdateTargetUnitCommandEvent 01.37	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 97 CommandManagerStateEvent 01.37	Serral          CommandManagerStateEvent
# 98 UpdateTargetUnitCommandEvent 01.38	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 98 CommandManagerStateEvent 01.38	Serral          CommandManagerStateEvent
# 98 UpdateTargetUnitCommandEvent 01.38	Serral          Right Click; Target: MineralField750 [01FC0001]; Location: (31.0, 37.5, 49104)
# 98 CommandManagerStateEvent 01.38	Serral          CommandManagerStateEvent
# 99 GetControlGroupEvent 01.39	Serral          GetControlGroupEvent
# 99 UpdateTargetUnitCommandEvent 01.39	Serral          Right Click; Target: MineralField750 [00E00001]; Location: (29.0, 41.5, 49104)
# 99 CommandManagerStateEvent 01.39	Serral          CommandManagerStateEvent
# 99 UpdateTargetUnitCommandEvent 01.39	Serral          Right Click; Target: MineralField750 [00E00001]; Location: (29.0, 41.5, 49104)
# 99 CommandManagerStateEvent 01.39	Serral          CommandManagerStateEvent
# 99 CameraEvent 01.39	Serral          CameraEvent at (93.62890625, 39.96875)
# 99 CameraEvent 01.39	Serral          CameraEvent at (36.5, 40.76171875)
# 100 PlayerStatsEvent 01.40	 Player 1 - Serral (Zerg) - Stats Update
# 100 UpdateTargetPointCommandEvent 01.40	Serral          Right Click; Location: (42.630859375, 44.109130859375, 49115)
# 100 CommandManagerStateEvent 01.40	Serral          CommandManagerStateEvent
# 100 CommandManagerStateEvent 01.40	Serral          CommandManagerStateEvent
# 100 SelectionEvent 01.40	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [3880001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3C80002]', 'Drone [3CC0001]', 'Drone [3D00001]', 'Drone [3E00001]', 'Drone [3F00001]']
# 100 GetControlGroupEvent 01.40	Serral          GetControlGroupEvent
# 100 SelectionEvent 01.40	Serral          SelectionEvent['Drone [3780001]', 'Drone [37C0001]', 'Drone [3800001]', 'Drone [3840001]', 'Drone [3880001]', 'Drone [38C0001]', 'Drone [3900001]', 'Drone [3940001]', 'Drone [3C40001]', 'Drone [3C80002]', 'Drone [3CC0001]', 'Drone [3D00001]', 'Drone [3E00001]', 'Drone [3F00001]']
# 101 GetControlGroupEvent 01.41	Serral          GetControlGroupEvent
