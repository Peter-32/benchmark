# %%
import sc2reader

# %%
replay = sc2reader.load_replay("../data/input/pro_data/00e6ed3e34a8c6fa1b0a0aa62892bffc.SC2Replay")
replay

# %%
replay.map_name
# Out:
# 'Blackrock LE'

# %%
replay.game_length
# Out:
# Length(seconds=607)

# %%
is_valid_release = replay.release_string >= '5.0.16'
is_valid_release
# Out:
# True

# %%
for player in replay.players:
    print(player.name, player.play_race, player.result)
# Out:
# Serral Zerg Win
# Geralt Protoss Loss
