# %%
import sc2reader
import pandas as pd
import numpy as np
import tqdm
from glob import glob
from utils import *

all_dfs = []
game_number = 0
for account in ['sample']:
    files = glob(f'../data/input/my_data/{account}/*')
    for file in tqdm.tqdm(files):
        
        try:
            replay = sc2reader.load_replay(file, load_map=True)
        except Exception as e:
            print(f"Failed to load {file}: {e}")
            continue
        if replay.map_name in ['Ruby Rock LE', 'Emerald City CE', 'Reclamation LE', 'Fields of Death', 'Gemgarden LE', 'New Bed of Chaos LE', 'Rhoskallian LE', 'Rust Bucket LE', 'Sludge City', 'Undercurrent LE', 'Yellowjacket', 'Phantom Mode']:
            continue
        game_number += 1
        assert replay.map_name in ['valid_maps', "At Eternity's Edge LE", 'Blackrock LE', 'Fear and Faith LE', 'Rainfall LE', 'Sanctuary III LE', 'Lockdown LE', 'Washout LE', 'Rorschach LE', 'Old Sun Temple LE'], replay.map_name

        is_valid_release = replay.release_string >= '5.0.16'
        assert is_valid_release, replay.release_string
        
        player1 = 'nemo'
        player2 = None
        player1_won = None
        player1_race = 'Zerg'
        player2_race = None
        for player in replay.players:
            if player.name == 'nemo' or player.name == 'Kairo':
                assert player.play_race == 'Zerg'
                player1_won = player.result
            else:
                if player2 != None:
                    raise Exception(player.name, player2)
                player2 = player.name
                player2_race = player.play_race
        print(player1, player2, player1_race, player2_race)

        inject_times_data = []
        for event in replay.events:
            seconds = event.frame / 22.4
            minutes = int(seconds // 60)
            remaining_seconds = int(seconds % 60)
            if seconds < 210:
                continue
        
            try:
                if player2 in str(event):
                    continue
                if event.player == player2:
                    continue
            except:
                pass

            print(3, seconds, event)
            if 'SpawnLarva' in str(event):
                print(1, seconds, event)
            # print(seconds, event)
            elif event.name == 'TargetUnitCommandEvent':
                print(2, seconds, event)
                if event.ability == None:
                    continue
                if event.ability.name == 'SpawnLarva':
                    inject_times_data.append(seconds)
            if seconds > 215:
                break
        inject_times_df = pd.DataFrame()
        inject_times_df['inject_time'] = inject_times_data
        inject_times_df['game_number'] = game_number
        inject_times_df['opponent_race'] = player2_race
        inject_times_df['game_length_seconds_max_600'] = int(np.round(seconds,0))
        inject_times_df['main_player_won'] = player1_won
        inject_times_df = inject_times_df[['game_number', 'opponent_race', 'game_length_seconds_max_600', 'inject_time', 'main_player_won']]
        all_dfs.append(inject_times_df)
inject_times_df = pd.concat(all_dfs, axis='index', ignore_index=True)
# local.write.csv(inject_times_df, '3_extract_my_injects')
# Out:
#  33%|███▎      | 1/3 [00:00<00:01,  1.64it/s]
# nemo Mandus Zerg Zerg
# 3 210.0 04.54	nemo            CameraEvent at (104.421875, 33.91015625)
# 3 210.04464285714286 04.54	nemo            CameraEvent at (101.47265625, 33.91015625)
# 3 210.13392857142858 04.54	nemo            CameraEvent at (98.953125, 33.91015625)
# 3 210.17857142857144 04.54	nemo            CameraEvent at (96.3125, 33.91015625)
# 3 210.26785714285717 04.54	nemo            CameraEvent at (90.59765625, 33.91015625)
# 3 210.3125 04.54	nemo            CameraEvent at (88.44921875, 33.91015625)
# 3 210.35714285714286 04.54	nemo            CameraEvent at (85.5625, 33.91015625)
# 3 210.44642857142858 04.54	nemo            GetControlGroupEvent
# 3 210.625 04.54	nemo            Ability (5C0) - Attack; Location: (83.97265625, 38.848388671875, 32749)
# 3 210.9375 04.55	nemo            Right Click; Location: (82.739990234375, 38.76513671875, 32749)
# 3 210.9375 04.55	nemo            CommandManagerStateEvent
# 3 211.29464285714286 04.55	nemo            Right Click; Location: (82.739990234375, 38.76513671875, 32749)
# 3 211.29464285714286 04.55	nemo            CommandManagerStateEvent
# 3 211.4732142857143 04.56	nemo            CameraEvent at (85.9921875, 33.91015625)
# 3 211.51785714285717 04.56	nemo            CameraEvent at (91.58203125, 35.56640625)
# 3 211.60714285714286 04.56	nemo            CameraEvent at (94.1640625, 38.1484375)
# 3 211.65178571428572 04.56	nemo            CameraEvent at (97.109375, 41.09765625)
# 3 211.69642857142858 04.56	 Player 2 - nemo (Zerg) - Unit born Larva [3F40002]
# 3 211.74107142857144 04.56	nemo            CameraEvent at (99.19921875, 41.7734375)
# 3 211.875 04.56	 Player 2 - nemo (Zerg) - Unit born Larva [4480001]
# 3 212.05357142857144 04.56	 Player 2 - nemo (Zerg) - Unit born Larva [4500001]
# 3 212.54464285714286 04.57	nemo            SelectionEvent['CreepTumorBurrowed [4180001]']
# 3 212.8125 04.57	 Player 2 - nemo (Zerg) - Unit born Drone [4580001]
# 3 212.8125 04.57	 Player 2 - nemo (Zerg) - Unit Larva [3D80002] type changed to Larva
# 3 212.8125 04.57	 Player 2 - nemo (Zerg) - Unit died Larva [3D80002].
# 3 212.85714285714286 04.58	 Player 2 - nemo (Zerg) - Unit born Larva [45C0001]
# 3 213.21428571428572 04.58	nemo            CameraEvent at (97.234375, 41.7734375)
# 3 213.25892857142858 04.58	nemo            CameraEvent at (94.34765625, 41.7734375)
# 3 213.3482142857143 04.58	nemo            CameraEvent at (88.87890625, 38.88671875)
# 3 213.39285714285717 04.58	nemo            CameraEvent at (85.9921875, 36.0)
# 3 213.48214285714286 04.58	nemo            CameraEvent at (83.47265625, 31.08203125)
# 3 213.83928571428572 04.59	nemo            CameraEvent at (83.47265625, 33.109375)
# 3 213.92857142857144 04.59	nemo            CameraEvent at (83.47265625, 36.3046875)
# 3 214.10714285714286 04.59	nemo            GetControlGroupEvent
# 3 214.2857142857143 05.00	 Player 2 - nemo (Zerg) - Stats Update
# 3 214.2857142857143 05.00	 Unit positions update
# 3 214.375 05.00	nemo            Right Click; Location: (82.54052734375, 36.8720703125, 32749)
# 3 214.375 05.00	nemo            CommandManagerStateEvent
# 3 214.6875 05.00	nemo            Right Click; Location: (82.253173828125, 36.472900390625, 32749)
# 3 214.6875 05.00	nemo            CommandManagerStateEvent
# 3 214.95535714285717 05.00	nemo            Right Click; Location: (82.57958984375, 36.62939453125, 32749)
# 3 214.95535714285717 05.00	nemo            CommandManagerStateEvent
# 3 215.13392857142858 05.01	nemo            GetControlGroupEvent
#  67%|██████▋   | 2/3 [00:01<00:00,  1.54it/s]
# nemo Red Zerg Terran
# 3 210.0 04.54	nemo            CameraEvent at (174.78125, 101.6171875)
# 3 210.2232142857143 04.54	nemo            Right Click; Target: Hatchery [037C0001]; Location: (181.5, 107.5, 49104)
# 2 210.2232142857143 04.54	nemo            Right Click; Target: Hatchery [037C0001]; Location: (181.5, 107.5, 49104)
# 3 210.35714285714286 04.54	nemo            Right Click; Target: Hatchery [037C0001]; Location: (181.5, 107.5, 49104)
# 3 210.35714285714286 04.54	nemo            CommandManagerStateEvent
# 3 210.5357142857143 04.54	nemo            CameraEvent at (174.53515625, 101.6171875)
# 3 210.58035714285717 04.54	nemo            CameraEvent at (171.64453125, 101.6171875)
# 3 210.66964285714286 04.54	 Player 2 - nemo (Zerg) - Unit born Larva [3EC0003]
# 3 210.66964285714286 04.54	nemo            CameraEvent at (166.36328125, 100.69921875)
# 3 210.71428571428572 04.55	nemo            CameraEvent at (166.36328125, 97.9921875)
# 3 210.80357142857144 04.55	nemo            CameraEvent at (166.36328125, 95.72265625)
# 3 210.8482142857143 04.55	 Player 2 - nemo (Zerg) - Unit born Larva [4300001]
# 3 211.02678571428572 04.55	 Player 2 - nemo (Zerg) - Unit born Larva [4380001]
# 3 211.11607142857144 04.55	nemo            CameraEvent at (178.5, 71.7578125)
# 3 212.00892857142858 04.56	nemo            SelectionEvent['Queen [3F40002]']
# 3 212.45535714285717 04.57	nemo            Ability (5C0) - Attack; Location: (178.71435546875, 76.784423828125, 57300)
# 3 213.30357142857144 04.58	nemo            Ability (E20) - SpawnLarva; Target: Hive [03080001]; Location: (178.5, 73.5, 57296)
# 1 213.30357142857144 04.58	nemo            Ability (E20) - SpawnLarva; Target: Hive [03080001]; Location: (178.5, 73.5, 57296)
# 3 213.6607142857143 04.59	nemo            CameraEvent at (181.5, 105.7578125)
# 3 214.2857142857143 05.00	 Player 2 - nemo (Zerg) - Stats Update
# 3 214.2857142857143 05.00	 Unit positions update
# 3 214.375 05.00	nemo            SelectionEvent['Queen [3F80002]']
# 3 214.50892857142858 05.00	 Player 2 - nemo (Zerg) - Unit born Larva [43C0003]
# 3 214.5982142857143 05.00	nemo            Right Click; Target: Hatchery [037C0001]; Location: (181.5, 107.5, 49104)
# 3 214.5982142857143 05.00	nemo            CommandManagerStateEvent
# 3 214.77678571428572 05.00	nemo            GetControlGroupEvent
# 3 215.04464285714286 05.01	nemo            SelectionEvent['Larva [39C0003]', 'Larva [3DC0003]', 'Larva [3EC0003]', 'Larva [4000002]', 'Larva [40C0001]', 'Larva [4180001]', 'Larva [4300001]', 'Larva [4380001]', 'Larva [43C0003]']
# 100%|██████████| 3/3 [00:02<00:00,  1.50it/s]
# nemo TheReckoner Zerg Protoss
# 3 210.0 04.54	nemo            CameraEvent at (41.7734375, 36.05859375)
# 3 210.04464285714286 04.54	nemo            CameraEvent at (41.7734375, 38.8828125)
# 3 210.13392857142858 04.54	nemo            CameraEvent at (41.7734375, 39.12890625)
# 3 210.80357142857144 04.55	 Player 1 - nemo (Zerg) - Unit born Larva [4BC0003]
# 3 210.8482142857143 04.55	nemo            SelectionEvent[]
# 3 210.98214285714286 04.55	 Player 1 - nemo (Zerg) - Unit born Larva [4E40001]
# 3 211.07142857142858 04.55	nemo            Ability (5C0) - Attack; Target: UnbuildablePlatesDestructible [00900001]; Location: (39.0, 43.0, 49104)
# 2 211.07142857142858 04.55	nemo            Ability (5C0) - Attack; Target: UnbuildablePlatesDestructible [00900001]; Location: (39.0, 43.0, 49104)
# 3 211.1607142857143 04.55	 Player 1 - nemo (Zerg) - Unit born Larva [4F00001]
# 3 211.42857142857144 04.56	nemo            CameraEvent at (41.7734375, 41.28125)
# 3 211.4732142857143 04.56	nemo            CameraEvent at (41.7734375, 43.4921875)
# 3 211.51785714285717 04.56	nemo            Right Click; Location: (38.209228515625, 48.874267578125, 49099)
# 3 211.51785714285717 04.56	nemo            CommandManagerStateEvent
# 3 211.51785714285717 04.56	nemo            CameraEvent at (41.7734375, 44.10546875)
# 3 211.875 04.56	nemo            Right Click; Location: (38.16650390625, 51.4306640625, 49099)
# 3 211.875 04.56	nemo            CommandManagerStateEvent
# 3 211.96428571428572 04.56	nemo            GetControlGroupEvent
# 3 212.23214285714286 04.57	nemo            Right Click; Location: (37.828857421875, 51.0419921875, 49099)
# 3 212.23214285714286 04.57	nemo            CommandManagerStateEvent
# 3 212.5 04.57	nemo            CameraEvent at (41.7734375, 44.71875)
# 3 212.54464285714286 04.57	nemo            CameraEvent at (41.7734375, 47.36328125)
# 3 212.67857142857144 04.57	nemo            GetControlGroupEvent
# 3 212.90178571428572 04.58	nemo            SelectionEvent['Larva [4640006]', 'Larva [4B40001]', 'Larva [4BC0003]', 'Larva [4C40001]', 'Larva [4D40001]', 'Larva [4E40001]', 'Larva [4F00001]']
# 3 213.08035714285717 04.58	 Player 1 - nemo (Zerg) - Unit Larva [4640006] type changed to Egg
# 3 213.08035714285717 04.58	nemo            Ability (1860) - MorphDrone
# 3 213.21428571428572 04.58	nemo            SelectionEvent['Larva [4640006]']
# 3 213.25892857142858 04.58	 Player 1 - nemo (Zerg) - Unit died Zergling [4840001].
# 3 213.25892857142858 04.58	 Player 1 - nemo (Zerg) - Unit Larva [4B40001] type changed to Egg
# 3 213.25892857142858 04.58	nemo            CommandManagerStateEvent
# 3 213.39285714285717 04.58	nemo            SelectionEvent['Larva [4B40001]']
# 3 213.52678571428572 04.58	 Player 1 - nemo (Zerg) - Unit born Larva [4DC0006]
# 3 213.6607142857143 04.59	nemo            GetControlGroupEvent
# 3 213.83928571428572 04.59	nemo            SelectionEvent['Larva [4BC0003]', 'Larva [4C40001]', 'Larva [4D40001]', 'Larva [4DC0006]', 'Larva [4E40001]', 'Larva [4F00001]']
# 3 214.0625 04.59	nemo            CameraEvent at (43.3125, 47.36328125)
# 3 214.10714285714286 04.59	nemo            CameraEvent at (45.15234375, 47.36328125)
# 3 214.15178571428572 04.59	nemo            CameraEvent at (50.0078125, 47.36328125)
# 3 214.24107142857144 04.59	nemo            CameraEvent at (52.95703125, 47.36328125)
# 3 214.2857142857143 05.00	 Player 1 - nemo (Zerg) - Stats Update
# 3 214.2857142857143 05.00	 Unit positions update
# 3 214.2857142857143 05.00	nemo            CameraEvent at (55.66015625, 47.36328125)
# 3 214.375 05.00	nemo            CameraEvent at (61.19140625, 47.36328125)
# 3 214.41964285714286 05.00	nemo            CameraEvent at (64.078125, 47.36328125)
# 3 214.50892857142858 05.00	nemo            CameraEvent at (69.484375, 47.36328125)
# 3 214.55357142857144 05.00	nemo            CameraEvent at (72.49609375, 47.36328125)
# 3 214.5982142857143 05.00	nemo            CameraEvent at (78.0234375, 47.36328125)
# 3 214.6875 05.00	nemo            CameraEvent at (78.640625, 47.36328125)
# 3 214.73214285714286 05.00	 Player 1 - nemo (Zerg) - Unit Larva [4BC0003] type changed to Egg
# 3 214.73214285714286 05.00	nemo            Ability (1862) - MorphOverlord
# 3 214.86607142857144 05.00	nemo            SelectionEvent['Larva [4BC0003]']
# 3 215.13392857142858 05.01	nemo            CameraEvent at (81.21875, 47.36328125)

# %%
output_df
# Out:
#    unspent_time  unspent_amount  game_number
# 0    300.000000             300            1
# 1    307.142857             220            1
# 2    314.285714             235            1
# 3    321.428571             262            1
# 4    328.571429             238            1
# 5    335.714286             158            1
# 6    342.857143             170            1
# 7    350.000000             140            1
