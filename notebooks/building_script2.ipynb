# %%
import sc2reader
import pandas as pd
import numpy as np
import tqdm
from glob import glob

game_number = 0
files = glob('../data/input/pro_data/*')
for file in tqdm.tqdm(files):
    game_number += 1
    try:
        replay = sc2reader.load_replay(file, load_map=True)
    except Exception as e:
        print(f"Failed to load {file}: {e}")
        continue
    
    assert replay.map_name in ['valid_maps', ''Blackrock LE', 'Fear and Faith LE', 'Rainfall LE', 'Sanctuary III LE', 'Lockdown LE', 'Washout LE', 'Rorschach LE', 'Old Sun Temple LE'], replay.map_name

    is_valid_release = replay.release_string >= '5.0.16'
    assert is_valid_release, replay.release_string
    
    player1 = 'Serral'
    player2 = None
    player1_won = None
    player1_race = 'Zerg'
    player2_race = None
    for player in replay.players:
        if player.name == 'Serral':
            assert player.play_race == 'Zerg'
            player1_won = player.result
        else:
            player2 = player.name
            player2_race = player.play_race
    print(player1, player2, player1_race, player2_race)
    
    inject_times_data = []
    for event in replay.events:
        seconds = event.frame / 22.4
        minutes = int(seconds // 60)
        remaining_seconds = int(seconds % 60)
        if seconds < 1:
            continue
    
        try:
            if playername != 'Serral':
                continue
        except:
            pass
    
        if event.name == 'TargetUnitCommandEvent':
            if event.ability == None:
                continue
            if event.ability.name == 'SpawnLarva':
                inject_times_data.append(seconds)
        if seconds > 10*60:
            break
    inject_times_df = pd.DataFrame()
    inject_times_df['inject_time'] = inject_times_data
    inject_times_df['game_number'] = game_number
    inject_times_df['opponent_race'] = player2_race
    inject_times_df['game_length_seconds_max_600'] = int(np.round(seconds,0))
    inject_times_df['main_player_won'] = player1_won
    inject_times_df = inject_times_df[['game_number', 'opponent_race', 'game_length_seconds_max_600', 'inject_time']]
    inject_times_df
# Out:
#   3%|▎         | 1/31 [00:00<00:28,  1.06it/s]
# Serral Geralt Zerg Protoss
#   6%|▋         | 2/31 [00:01<00:24,  1.21it/s]
# Serral SKillous Zerg Protoss
#  10%|▉         | 3/31 [00:02<00:24,  1.14it/s]
# Serral ratgameplay Zerg Terran
#  13%|█▎        | 4/31 [00:04<00:31,  1.16s/it]
# Serral SKillous Zerg Protoss
#  16%|█▌        | 5/31 [00:05<00:27,  1.06s/it]
# Serral Reynor Zerg Zerg
#  19%|█▉        | 6/31 [00:06<00:25,  1.02s/it]
# Serral liquidclem Zerg Terran
#  23%|██▎       | 7/31 [00:07<00:24,  1.01s/it]
# Serral Geralt Zerg Protoss
#  26%|██▌       | 8/31 [00:07<00:21,  1.07it/s]
# Serral SKillous Zerg Protoss
#  29%|██▉       | 9/31 [00:09<00:23,  1.07s/it]
# Serral Reynor Zerg Zerg
#  32%|███▏      | 10/31 [00:10<00:21,  1.02s/it]
# Serral ratgameplay Zerg Terran
#  35%|███▌      | 11/31 [00:11<00:24,  1.24s/it]
# Serral liquidclem Zerg Terran
#  39%|███▊      | 12/31 [00:12<00:21,  1.13s/it]
# Serral Vaeda Zerg Protoss
#  42%|████▏     | 13/31 [00:13<00:21,  1.17s/it]
# Serral Harstem Zerg Protoss
#  45%|████▌     | 14/31 [00:15<00:21,  1.25s/it]
# Serral liquidclem Zerg Terran
#  48%|████▊     | 15/31 [00:16<00:18,  1.14s/it]
# Serral Cellsidus Zerg Zerg
#  52%|█████▏    | 16/31 [00:17<00:19,  1.30s/it]
# Serral liquidclem Zerg Terran
#  55%|█████▍    | 17/31 [00:18<00:16,  1.17s/it]
# Serral liquidclem Zerg Terran
#  58%|█████▊    | 18/31 [00:20<00:15,  1.22s/it]
# Serral Reynor Zerg Zerg
#  61%|██████▏   | 19/31 [00:21<00:13,  1.11s/it]
# Serral Lambo Zerg Zerg
#  65%|██████▍   | 20/31 [00:22<00:14,  1.30s/it]
# Serral Reynor Zerg Zerg
#  68%|██████▊   | 21/31 [00:23<00:11,  1.16s/it]
# Serral Vaeda Zerg Protoss
#  71%|███████   | 22/31 [00:25<00:11,  1.31s/it]
# Serral Reynor Zerg Zerg
#  74%|███████▍  | 23/31 [00:26<00:09,  1.24s/it]
# Serral Reynor Zerg Zerg
#  77%|███████▋  | 24/31 [00:28<00:10,  1.51s/it]
# Serral Lambo Zerg Zerg
#  81%|████████  | 25/31 [00:30<00:09,  1.55s/it]
# Serral Reynor Zerg Zerg
#  84%|████████▍ | 26/31 [00:31<00:07,  1.51s/it]
# Serral Lambo Zerg Zerg
#  87%|████████▋ | 27/31 [00:32<00:05,  1.29s/it]
# Serral Harstem Zerg Protoss
#  87%|████████▋ | 27/31 [00:33<00:04,  1.24s/it]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[69], line 17
#      13     except Exception as e:
#      14         print(f"Failed to load {file}: {e}")
#      15         continue
#      16
# ---> 17     assert replay.map_name in ['valid_maps', 'Blackrock LE', 'Fear and Faith LE', 'Rainfall LE', 'Sanctuary III LE', 'Lockdown LE', 'Washout LE', 'Rorschach LE', 'Old Sun Temple LE'], replay.map_name
#      18
#      19     is_valid_release = replay.release_string >= '5.0.16'
#      20     assert is_valid_release, replay.release_string
#
# AssertionError: At Eternity's Edge LE
